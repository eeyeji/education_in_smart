# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import random

# %%
from matplotlib import font_manager, rc  
font_name = font_manager.FontProperties(fname='C:/Windows/Fonts/malgun.ttf').get_name()
rc('font', family=font_name)

# %%
data= pd.read_csv('Traffic_Accident_2017.csv', encoding = 'euc-kr')
data
# Out:
#        발생년      발생년월일시  발생분  주야 요일  사망자수  사상자수  중상자수  경상자수  부상신고자수  ...  \
# 0     2017  2017010101   15  야간  일     1     2     1     0       0  ...
# 1     2017  2017010102   28  야간  일     1     1     0     0       0  ...
# 2     2017  2017010102   43  야간  일     1     2     0     1       0  ...
# 3     2017  2017010102   22  야간  일     1     1     0     0       0  ...
# 4     2017  2017010104   37  야간  일     1     1     0     0       0  ...
# ...    ...         ...  ...  .. ..   ...   ...   ...   ...     ...  ...
# 4060  2017  2017123118   10  야간  일     1     4     1     0       2  ...
# 4061  2017  2017123118   25  야간  일     1     1     0     0       0  ...
# 4062  2017  2017123119   55  야간  일     1     1     0     0       0  ...
# 4063  2017  2017123120   40  야간  일     1    11     1     9       0  ...
# 4064  2017  2017123123   15  야간  일     1     1     0     0       0  ...
#
#      도로형태_대분류   도로형태 당사자종별_1당_대분류  당사자종별_1당 당사자종별_2당_대분류 당사자종별_2당 발생위치X_UTMK  \
# ...

# %%
#요일별 사고 건수를 세봅시다
temp=data['요일'].value_counts()
temp
# Out:
# 화    608
# 월    603
# 금    603
# 토    596
# 목    586
# 수    565
# 일    504
# Name: 요일, dtype: int64

# %%
#노가다필요- 가나다순이기때문에 월~일로는 표현이 안됨
y = temp[['월', '화', '수', '목', '금', '토', '일']]
y
# Out:
# 월    603
# 화    608
# 수    565
# 목    586
# 금    603
# 토    596
# 일    504
# Name: 요일, dtype: int64

# %%
x=y.index
plt.bar(x, y, label='사고건수')
plt.legend()

plt.xlabel('요일')
plt.ylabel('사고 건수').set_rotation(0)

#범위 바꿔주기
plt.ylim([500, 600])

plt.title('2017년 요일별 사망교통사고 건수')

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#'사고유형_대분류' 칼럼에서 '차대차'만 뽑아오기
car=data[data['사고유형_대분류']=='차대차']
car
# Out:
#        발생년      발생년월일시  발생분  주야 요일  사망자수  사상자수  중상자수  경상자수  부상신고자수  ...  \
# 0     2017  2017010101   15  야간  일     1     2     1     0       0  ...
# 2     2017  2017010102   43  야간  일     1     2     0     1       0  ...
# 8     2017  2017010118   33  야간  일     1     3     1     1       0  ...
# 9     2017  2017010120    0  야간  일     1     7     4     2       0  ...
# 17    2017  2017010209    0  주간  월     1     2     1     0       0  ...
# ...    ...         ...  ...  .. ..   ...   ...   ...   ...     ...  ...
# 4050  2017  2017123009   58  주간  토     1     1     0     0       0  ...
# 4055  2017  2017123023   50  야간  토     1     6     2     3       0  ...
# 4058  2017  2017123112   10  주간  일     1     1     0     0       0  ...
# 4060  2017  2017123118   10  야간  일     1     4     1     0       2  ...
# 4063  2017  2017123120   40  야간  일     1    11     1     9       0  ...
#
#      도로형태_대분류   도로형태 당사자종별_1당_대분류 당사자종별_1당 당사자종별_2당_대분류 당사자종별_2당 발생위치X_UTMK  \
# ...

# %%
#car에서 발생지시도를 기준으로 사상자수의 합계 구하기
#                                    발생지시도 순으로 보겠다.
place=car[['사상자수', '발생지시도']].groupby("발생지시도").sum()
place
# Out:
#        사상자수
# 발생지시도
# 강원      214
# 경기      824
# 경남      248
# 경북      287
# 광주       87
# 대구      115
# 대전       61
# 부산      107
# 서울      197
# 세종       17
# 울산       73
# 인천       66
# 전남      298
# 전북      244
# 제주       50
# 충남      351
# 충북      261

# %%
x=place.index
y=place.values

plt.plot(x,y, label='지역별 사상자수 합계')
plt.legend()

plt.xlabel('지역')
plt.ylabel('사상자수').set_rotation(0)

plt.title('2017년 차vs차 교통사고 사상자수 합계')

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ##### 9.23 복습
# - 파이차트
# - 교통사고가 많이 일어나는 시간대를 알아보고 시각화 하기

# %%
#발생년월일시에서 시만 출력하기
time = car.발생년월일시
time%=100
time
# Out:
# 0        1
# 2        2
# 8       18
# 9       20
# 17       9
#         ..
# 4050     9
# 4055    23
# 4058    12
# 4060    18
# 4063    20
# Name: 발생년월일시, Length: 1642, dtype: int64

# %% [markdown]
# - 만들어 놓은 time 데이터를 활용하여 카테고리화 시켜주기 - 구간 나누기

# %%
#bins: 구간 - 왼쪽초과 오른쪽이하
bins=[-1, 2, 5, 8, 11, 14, 17, 20, 23]

#labels: 구분
labels=["0-2", "3-5", "6-8", "9-11", "12-14", "15-17", "18-20", "21-23"]

result = pd.cut(time, bins, labels=labels)
result
# Out:
# 0         0-2
# 2         0-2
# 8       18-20
# 9       18-20
# 17       9-11
#         ...
# 4050     9-11
# 4055    21-23
# 4058    12-14
# 4060    18-20
# 4063    18-20
# Name: 발생년월일시, Length: 1642, dtype: category
# Categories (8, object): ['0-2' < '3-5' < '6-8' < '9-11' < '12-14' < '15-17' < '18-20' < '21-23']

# %% [markdown]
# - 파이차트 만들기

# %%
#시간대에 해당하는 사고건수 세주기
rs = result.value_counts()
rs
# Out:
# 15-17    260
# 9-11     248
# 12-14    232
# 18-20    231
# 6-8      204
# 21-23    182
# 3-5      161
# 0-2      124
# Name: 발생년월일시, dtype: int64

# %%
#                          정렬해주기
rs = result.value_counts().sort_index()
rs
# Out:
# 0-2      124
# 3-5      161
# 6-8      204
# 9-11     248
# 12-14    232
# 15-17    260
# 18-20    231
# 21-23    182
# Name: 발생년월일시, dtype: int64

# %%
plt.figure(figsize=(5,5))

#     데이터   라벨이름                소수점 한자리까지 실수로 표현
plt.pie(rs, labels=labels, autopct="%1.1f%%")

plt.show()

# %%
plt.figure(figsize=(5,5))

#     데이터   라벨이름                소수점 한자리까지 실수로 표현
#plt.pie(rs, labels=labels, autopct="%1.1f%%")

#파이 간격 떨어트리기 0: 붙어있음 10: 10% 떨어짐
explode=[0, 0.10, 0, 0.10, 0, 0.10, 0, 0.10]

#                                              시계반대방향           파이 간격      그림자 추가
plt.pie(rs, labels=labels, autopct="%1.1f%%", counterclock=False, explode=explode, shadow=True )

plt.show()

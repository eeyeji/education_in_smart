# %%
# !pip install webdriver_manager

from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd
import time
from bs4 import BeautifulSoup as bs
from selenium.webdriver.common.keys import Keys

driver = webdriver.Chrome(ChromeDriverManager().install())

#sbs뉴스-최신뉴스
driver.get("https://news.sbs.co.kr/news/newsflash.do?plink=NEW&cooper=SBSNEWSMAIN")
driver.maximize_window()
time.sleep(1)

#객체화
soup = bs(driver.page_source, 'html.parser')

title_list = []
text_list = []

#url 보관
#https://news.sbs.co.kr/news/newsflash.do?pageDate=20220915&pageIdx=2
url_list = []
for i in range(1, 6):
    page_url = f'https://news.sbs.co.kr/news/newsflash.do?pageDate=20220915&pageIdx={i}'
    print(page_url)
    driver.get(page_url)
    #웹페이지 변동시 로딩시간 주는게 좋음
    time.sleep(1)


    for i in range(1, 11):
        img = driver.find_element_by_css_selector(f'#container > div > div.w_news_list.type_issue > ul > li:nth-child({i}) > a.news > span > img')
        img.click()
        #기사 제목 추출
        #print('제목: ')
        title = driver.find_elements_by_css_selector('#vmNewsTitle')
        #for i in title:
        #    print(i.text)

        for i in title:
            title_list.append(i.text)

        #기사내용 추출
        #print('내용: ')
        text = driver.find_elements_by_css_selector('#container > div.w_inner > div.w_article > div.w_article_cont > div.w_article_left > div.article_cont_area > div.main_text > div')
        #for i in text:
        #    print(i.text)
        for i in text:
            text_list.append(i.text)
        driver.back()

    
    search = soup.select('a.news')
    for i in search:
        url_list.append('https://news.sbs.co.kr/'+i['href'])



    
data = {'기사제목' : title_list, '기사내용' : text_list}
sbsNews = pd.DataFrame(data)
sbsNews
# Out:
# Requirement already satisfied: webdriver_manager in c:\users\user\anaconda3\lib\site-packages (3.8.3)
# Requirement already satisfied: requests in c:\users\user\anaconda3\lib\site-packages (from webdriver_manager) (2.27.1)
# Requirement already satisfied: python-dotenv in c:\users\user\anaconda3\lib\site-packages (from webdriver_manager) (0.21.0)
# Requirement already satisfied: tqdm in c:\users\user\anaconda3\lib\site-packages (from webdriver_manager) (4.64.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\lib\site-packages (from requests->webdriver_manager) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\lib\site-packages (from requests->webdriver_manager) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\user\anaconda3\lib\site-packages (from requests->webdriver_manager) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\user\anaconda3\lib\site-packages (from requests->webdriver_manager) (2.0.4)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\lib\site-packages (from tqdm->webdriver_manager) (0.4.4)
# https://news.sbs.co.kr/news/newsflash.do?pageDate=20220915&pageIdx=1
# https://news.sbs.co.kr/news/newsflash.do?pageDate=20220915&pageIdx=2
# https://news.sbs.co.kr/news/newsflash.do?pageDate=20220915&pageIdx=3
# https://news.sbs.co.kr/news/newsflash.do?pageDate=20220915&pageIdx=4
# https://news.sbs.co.kr/news/newsflash.do?pageDate=20220915&pageIdx=5
#                                               기사제목  \
# 0                  레드카펫 위 '핑크 드레스'…'왕실 조롱' 태국인의 최후
# 1                      신종 마약 유통 · 투약한 태국인 등 27명 송치
# 2                      [자막뉴스] 김정은 옆 밀착 수행…새 얼굴의 정체
# 3              '라스트 찬스' 이강인, 실력으로 벤투 고집 꺾었다 [축덕쑥덕]
# 4              [자막뉴스] 여성 역무원 살해한 30대 남성…화장실까지 따라갔다
# 5                   조정훈 "특검은 핵폭탄" 박범계 "우리는 국민을 대변"
# 6                     양양 낙산에서 건물 진동…숙박업소 투숙객 대피 소동
# 7                        추석날 호텔서 마약 투약한 남녀 검찰에 넘겨져
# 8                '마약 투여' 유명 남성잡지 모델, 2심도 징역 8개월 실형
# 9            국민의힘 이용호, 원내대표 출마 선언 "외연 확장 상징 선택해달라"
# 10                  피겨 유영, 시즌 첫 국제 대회 쇼트 1위…김예림 5위
# 11  [영상] 울산서 검거된 '뉴질랜드 경매 가방 속 시신' 용의자…"아이들 친모 유력"
# 12                  미국 이어 영국도 "러, 재고부족에 북한서 무기 조달"
# 13           윤 대통령 "물가 먼저 잡는 게 우선이란 기조…금리부담 경감 조치"
# 14               신규 확진 7만 1,471명…해외유입 622명 역대 두 번째
# 15          [Pick] 가발 쓰고 여장한 20대, 여탕 들어가 50분간 지켜봤다
# 16           [Pick] 시각장애인이 산 그 우유, 유통기한 점자 표시도 없었다
# 17         윤 대통령 "태양광, 이권 카르텔 비리에 혈세 사용돼 개탄…사법 처리"
# 18              미 "EU와 전기차 세액공제안 계속 논의"…한미도 곧 실무협의
# 19                [취재파일] '음주운전' 김민석, 밀라노올림픽 출전 불투명
# 20                인천공항, 세계 유일 '5성급' 공인…고객경험인증 최고등급
# 21            인천상륙작전 72주년 전승 행사 개최…"자유 · 평화 지킨 승리"
# 22               조응천 "'탄핵' 입에 올릴 단어 아냐…언급할 가치도 없어"
# 23             친정팀 울린 홀란의 결승골…맨시티, 도르트문트에 2대 1 역전승
# 24                  국방차관, 미 국방 연구차관과 국방 · 방산 협력 논의
# 25                  네이버 · 쿠팡서 면세품 살 수 있다…입국 수령도 가능
# 26                 [취재파일] 윤 대통령의 습관성 '-구나' 사용에 대하여
# 27                        성범죄 피의자 경찰서 주차장서 도주…추적 중
# 28       [속보] 신규 확진 7만 1471명, 전날보다 2만여 명 줄어…사망 72명
# 29         윤 대통령 "태양광, 이권 카르텔 비리에 혈세 사용돼 개탄…사법 처리"
# 30             '유산 아픔' 진태현 "박시은과 매일 함께…아직 달력은 못 봐"
# 31                 "정말 싫어!" 짜증 폭발한 찰스 3세…또 만년필 때문?
# 32        [뉴스딱] "미개봉 25만 원" 중고시장에 풀린 '윤 대통령 기념 시계'
# 33             [뉴스딱] 가게 밖 햇빛 노출된 페트병 생수…"유해 물질 위험"
# 34         [뉴스딱] "고기 굽기 금지"…1박 30만 원짜리 펜션 갔는데 '황당'
# 35               수해민 두 번 울리는 좀도둑…침수된 집과 차량 노려 '슬쩍'
# 36                   '교통사고 중상' 의원 비서관, 출동 경찰 2명 고소
# 37           인권위, "쿠팡 물류센터 내 휴대전화 반입 금지는 부당" 의견 표명
# 38              바이든, 북미 오토쇼서 미국차 홍보…"제조업 미래는 우리 것"
# 39                   "좋은 파트너 될 것" 구글, 제주에 투자 의사 밝혀
# 40                   "좋은 파트너 될 것" 구글, 제주에 투자 의사 밝혀
# 41          '교단 누운 중학생' 휴대폰 속 교사 사진 없었다…"법적 처벌 불가"
# 42                    신당역 여자화장실서 역무원 살해한 30대 남성 체포
# 43                여교사 뒤에 누워서 스마트폰 든 중학생…경찰 "사진 없음"
# 44                 뉴질랜드 '가방 속 아이 시신'…용의자, 울산서 검거됐다
# 45              미국 주택담보대출 금리, 2008년 금융위기 후 첫 6% 돌파
# 46               예금 동결 레바논서 은행에 장난감 총 들고 난입해 인출 요구
# 47                 '물 반 멸치 반'…태풍 지나자 부산 해수욕장에 멸치 떼
# 48                    "생활비 마련하려"…대낮 금은방 턴 간 큰 10대들
# 49                 검찰, '테라 · 루나' 권도형 체포영장…신병 확보 나서
#
#                                                  기사내용
# 0   태국도 영국처럼 입헌군주제를 채택한 국가인데요.\n\n한 활동가가 왕비의 차림을 흉...
# 1   신종 마약을 국내에 유통하고 투약한 일당이 경찰에 붙잡혔습니다.\n\n경기 용인 동...
# 2   북한 김정은 총비서 옆에서 밀착 수행을 하는 한 여성이 포착됐습니다. 북한이 비핵화...
# 3   [골룸] 축덕쑥덕 184 : '라스트 찬스' 이강인, 실력으로 벤투 고집 꺾었다\n...
# 4   어젯(14일)밤 서울 지하철 2호선 신당역에 있는 여자화장실에서 30대 남성이 흉기...
# 5   시대전환 조정훈(비례대표) 대표는 오늘(15일) 더불어민주당이 추진하는 '김건희 특...
# 6   ▲위 사진은 기사 내용과 관련이 없습니다.\n\n지난달 땅 꺼짐으로 편의점 건물 일...
# 7   추석날 호텔에서 마약을 투약한 남녀가 검찰에 넘겨졌습니다.\n\n오늘(15일) 광주...
# 8   유명 남성 잡지 모델 출신 30대 여성이 마약을 투약한 혐의로 항소심에서도 실형을 ...
# 9   국민의힘 재선 의원인 이용호 의원이 오늘(15일) 오전 국회에서 기자회견을 열어 오...
# 10  피겨스케이팅 여자 싱글 간판 유영이 2022-2023시즌 처음 출전한 국제대회 쇼트...
# 11  뉴질랜드에서 발생한 '가방 속 어린이 시신 사건'의 용의자가 오늘(15일) 새벽 울...
# 12  ▲위 사진은 기사 내용과 관련이 없습니다.\n\n미국에 이어 영국도 러시아가 우크라...
# 13  윤석열 대통령은 금리 인상 우려와 관련해 "금융 채무가 많은 서민의 민생 안정을 위...
# 14  어제(14일) 하루 코로나19 신규 확진자는 7만 1천471명입니다.\n\n지난주 ...
# 15  ▲ 위 사진은 기사 내용과 직접적인 관련이 없습니다.\n\n여장을 하고 여자 목욕탕...
# 16  음료와 컵라면, 우유 제품 10개 중 6개는 유통기한 등에 관한 점자 표시가 없어 ...
# 17  윤석열 대통령이 문재인 정부 시절 태양광 사업 비리와 관련해 "참 개탄스럽다"고 밝...
# 18  북미에서 생산된 전기차에 대해서만 세액공제 혜택을 주는 미국의 인플레이션 감축법(I...
# 19  음주운전 사고를 내 징계를 당했던 전 스피드스케이팅 남자 국가대표 김민석 선수(성남...
# 20  인천국제공항이 세계 최초이자 유일한 '5성급' 공항으로 이름을 올렸습니다.\n\n인...
# 21  해군은 인천시와 공동으로 14∼15일 인천 일대에서 제72주년 인천상륙작전 전승 행...
# 22  더불어민주당 조응천 의원은 오늘(15일) 당 일각에서 윤석열 대통령의 탄핵을 시사하...
# 23  유럽축구 챔피언스리그에서 맨체스터 시티의 '괴물 공격수' 엘링 홀란이 친정팀 보루시...
# 24  고위급 확장억제전략협의체(EDSCG) 회의 참석차 미국 워싱턴DC를 방문 중인 신범...
# 25  <앵커>\n\n친절한 경제 시간입니다. 한지연 기자 나와 있습니다. 앞으로 온라인에...
# 26  윤석열 대통령 특유의 종결 어미 사용 습관에 대해 친한 기자들과 이야기를 나누다 이...
# 27  성범죄 피의자가 경찰서 주차장에서 감시가 허술한 틈을 타 도주해 경찰이 추적에 나섰...
# 28  신규 확진 7만 1471명, 전날보다 2만여 명 줄어…사망 72명\n\n(SBS 디...
# 29  윤석열 대통령은 오늘(15일) 문재인 정부 시절 태양광 사업 비리와 관련 "참 개탄...
# 30  배우 진태현이 박시은과의 근황을 밝혔다.\n\n진태현은 14일 자신의 SNS에 사진...
# 31  엘리자베스 2세 여왕 서거로 왕위를 물려받은 찰스 3세가 공식 일정 중 짜증을 내는...
# 32  윤석열 대통령 기념 시계가 중고 거래 사이트에서 많게는 원가의 다섯 배 가격으로 거...
# 33  페트병에 담긴 생수가 오랜 기간 햇빛에 노출되면 포름알데히드 등 유해 물질이 발생할...
# 34  한 펜션의 이용안내문 관련된 이야기인데요, 연기와 냄새나는 음식을 조리하지 말라는 ...
# 35  태풍 힌남노로 큰 피해를 입은 경북 포항에선 태풍으로 침수된 집과 차량이 절도범들의...
# 36  고속도로에서 교통사고를 당해 중상을 입은 국회의원 비서관이 초동 조치가 부실했다며 ...
# 37  국가인권위원회가 물류센터 작업장 내 휴대전화 반입을 금지하는 쿠팡의 지침이 부당하다...
# 38  조 바이든 미국 대통령이 현지 시간 14일 미시간주 디트로이트에서 열린 '2022 ...
# 39  다국적 기업인 '구글'(Google)이 제주에 대한 투자 의사를 밝혀 귀추가 주목됩...
# 40  다국적 기업인 '구글'(Google)이 제주에 대한 투자 의사를 밝혀 귀추가 주목됩...
# 41  지난달, 충남 홍성의 한 중학교에서 한 학생이 수업 중 교단에 누워 수업 중인 여교...
# 42  서울 지하철 2호선 신당역 여자화장실에서 20대 여성 역무원을 살해한 남성이 경찰에...
# 43  중학생이 수업 중 교단에 드러누워 여성 교사 뒤에서 스마트폰(휴대전화)을 들었던 것...
# 44  뉴질랜드 '가방 속 어린이 시신 사건'의 용의자로 지목된 현지 국적 여성이 울산에서...
# 45  미국 연방준비제도(Fed·연준)의 가파른 기준금리 인상 여파로 미국의 모기지(주택담...
# 46  이미지 확대하기\n\n최악의 경제난을 겪고 있는 중동국가 레바논에서 은행당국의 출금...
# 47  <앵커>\n\n태풍 힌남노가 지나간 뒤 부산 해수욕장 곳곳에 멸치 떼가 등장했습니다...
# 48  <앵커>\n\n대낮에 울산 도심에서 10대들이 금은방 주인을 폭행하고 수천만 원의 ...
# 49  <앵커>\n\n가상화폐 루나와 테라 사태를 수사하고 있는 검찰이 권도형 테라폼랩스 ...

# %% [markdown]
# #### selet로 url추출

# %%
# url가져오기-href
# 기본구조: <a href = "참조 url" class = 'nnn'> _____</a>
search = soup.select('a.news')

#for문으로 href추출
for i in search:
    #href를 실제 사용할 수 있는 url로 만들어주는 방법: 
    print('https://news.sbs.co.kr/' + i['href'])

    #print(i.text)
    #-> 뉴스 제목 나옴
# Out:
# https://news.sbs.co.kr//news/endPage.do?news_id=N1006896893
# https://news.sbs.co.kr//news/endPage.do?news_id=N1006896370
# https://news.sbs.co.kr//news/endPage.do?news_id=N1006896934
# https://news.sbs.co.kr//news/endPage.do?news_id=N1006896910
# https://news.sbs.co.kr//news/endPage.do?news_id=N1006896317
# https://news.sbs.co.kr//news/endPage.do?news_id=N1006896854
# https://news.sbs.co.kr//news/endPage.do?news_id=N1006896870
# https://news.sbs.co.kr//news/endPage.do?news_id=N1006896860
# https://news.sbs.co.kr//news/endPage.do?news_id=N1006896859
# https://news.sbs.co.kr//news/endPage.do?news_id=N1006896841

# %% [markdown]
# #### find로 url추출

# %%
search2 = soup.find_all('a', class_='news')
#for문으로 href추출
for i in search:
    #href를 실제 사용할 수 있는 url로 만들어주는 방법: 
    print('https://news.sbs.co.kr/' + i['href'])

    #print(i.text)
    #-> 뉴스 제목 나옴
# Out:
# https://news.sbs.co.kr//news/endPage.do?news_id=N1006896400
# https://news.sbs.co.kr//news/endPage.do?news_id=N1006896846
# https://news.sbs.co.kr//news/endPage.do?news_id=N1006896903
# https://news.sbs.co.kr//news/endPage.do?news_id=N1006896850
# https://news.sbs.co.kr//news/endPage.do?news_id=N1006896789
# https://news.sbs.co.kr//news/endPage.do?news_id=N1006896739
# https://news.sbs.co.kr//news/endPage.do?news_id=N1006896742
# https://news.sbs.co.kr//news/endPage.do?news_id=N1006896741
# https://news.sbs.co.kr//news/endPage.do?news_id=N1006896740
# https://news.sbs.co.kr//news/endPage.do?news_id=N1006896738

# %% [markdown]
# #### 페이지 넘기기

# %%
#url 보관
#https://news.sbs.co.kr/news/newsflash.do?pageDate=20220915&pageIdx=2
url_list = []
for i in range(1, 6):
    page_url = f'https://news.sbs.co.kr/news/newsflash.do?pageDate=20220915&pageIdx={i}'
    print(page_url)
    driver.get(page_url)

    #웹페이지 변동시 로딩시간 주는게 좋음
    time.sleep(1)

    #soup = bs(driver.page_source, 'html.parser')
    search = soup.select('a.news')
    for i in search:
        url_list.append('https://news.sbs.co.kr/'+i['href'])
# Out:
# https://news.sbs.co.kr/news/newsflash.do?pageDate=20220915&pageIdx=1
# https://news.sbs.co.kr/news/newsflash.do?pageDate=20220915&pageIdx=2
# https://news.sbs.co.kr/news/newsflash.do?pageDate=20220915&pageIdx=3
# https://news.sbs.co.kr/news/newsflash.do?pageDate=20220915&pageIdx=4
# https://news.sbs.co.kr/news/newsflash.do?pageDate=20220915&pageIdx=5

# %% [markdown]
# #### 9/14 누르기

# %%
date = driver.find_element_by_xpath('//*[@id="container"]/div/div[3]/div/ol/li[2]/a')
date.click()

# %% [markdown]
# #### 기사제목, 내용 추출하기

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd
import time
from bs4 import BeautifulSoup as bs
from selenium.webdriver.common.keys import Keys

driver = webdriver.Chrome(ChromeDriverManager().install())

#sbs뉴스-최신뉴스
driver.get("https://news.sbs.co.kr/news/newsflash.do?plink=NEW&cooper=SBSNEWSMAIN")
driver.maximize_window()
time.sleep(1)

#객체화
soup = bs(driver.page_source, 'html.parser')

for i in range(1, 11):
    img = driver.find_element_by_css_selector(f'#container > div > div.w_news_list.type_issue > ul > li:nth-child({i}) > a.news > span > img')
    img.click()
    #기사 제목 추출
    print('제목: ')
    title = driver.find_elements_by_css_selector('#vmNewsTitle')
    for i in title:
        print(i.text)

    #기사내용 추출
    print('내용: ')
    text = driver.find_elements_by_css_selector('#container > div.w_inner > div.w_article > div.w_article_cont > div.w_article_left > div.article_cont_area > div.main_text > div')
    for i in text:
        print(i.text)
    driver.back()
# Out:
# 제목:
# [자막뉴스] 김정은 옆 밀착 수행…새 얼굴의 정체
# 내용:
# 북한 김정은 총비서 옆에서 밀착 수행을 하는 한 여성이 포착됐습니다. 북한이 비핵화는 없다며 핵무력을 법제화한 날에 보였는데요. 이 여성의 정체가 뭔지, 영상으로 확인하실 수 있습니다.
# 제목:
# '라스트 찬스' 이강인, 실력으로 벤투 고집 꺾었다 [축덕쑥덕]
# 내용:
# [골룸] 축덕쑥덕 184 : '라스트 찬스' 이강인, 실력으로 벤투 고집 꺾었다
#
# '골든 보이' 이강인이 마침내 벤투호에 재승선했습니다.
#
# 이강인은 9월 A매치 평가전 명단에 포함돼 1년 6개월 만에 다시 대표팀에 합류했습니다.
#
# 이번 시즌 스페인 라리가 마요르카에서 4경기 연속 공격포인트를 기록하는 등 절정의 공격 본능을 선보인 데다,
#
# 약점으로 지적된 수비 능력까지 일취월장한 모습으로 그를 외면했던 벤투 감독의 고집을 꺾었습니다.
#
# 이강인이 마요르카에서 '프리롤'을 부여받아 날개를 펼친 것처럼 벤투호에서도 '프리롤'의 임무를 수행할 수 있을지, 월드컵 전 마지막 실험이 펼쳐질 전망입니다.
#
# 이강인과 달리 수원FC의 이승우는 이번에도 외면받았습니다.
#
# K리그에서 눈부신 활약에도 벤투의 마음을 사로잡지 못했습니다.
#
# 벤투호의 9월 A매치 평가전 명단 분석과 갈수록 흥미로워지는 K리그 이야기, 축덕쑥덕에서 함께 하세요.
#
# 주영민 기자, 주시은 아나운서, 하성룡 기자, 박진형 PD가 함께합니다.
#
# * fb@sbs.co.kr : 여러분의 메일을 기다리고 있습니다. 질문과 사연 많이 보내주세요.
#
# 00:16:10 청취자 질문: ① 아시아 네이션스리그 창설
# 00:20:29 이슈 포커스: ① 벤투 고집에 왼발 마법 건 이강인...대표팀 26인 명단 발표
# 00:39:24 이슈 포커스: ② 밤잠 설칠 일 없다...수면제 경기력과 길어지는 골 침묵
# 00:51:25 이슈 포커스: ③ 노는 물이 갈린다...남은 한 자리는 수원FC·강원 중 누구?
#
# ▶ <골룸: 골라듣는 뉴스룸> 팟캐스트는 '팟빵', '네이버 오디오클립', '애플 팟캐스트'에서도 들을 수 있습니다.
# - '팟빵' 접속하기
# - '네이버 오디오클립' 접속하기
# - '애플 팟캐스트'로 접속하기
# 제목:
# [자막뉴스] 여성 역무원 살해한 30대 남성…화장실까지 따라갔다
# 내용:
# 어젯(14일)밤 서울 지하철 2호선 신당역에 있는 여자화장실에서 30대 남성이 흉기를 휘둘러 20대 여성 역무원이 숨졌습니다.
#
# 붙잡힌 피의자에게 저희 취재팀이 직접 범행동기 등을 캐물어봤습니다. 자세한 내용 영상으로 확인하시죠.
# 제목:
# 조정훈 "특검은 핵폭탄" 박범계 "우리는 국민을 대변"
# 내용:
# 시대전환 조정훈(비례대표) 대표는 오늘(15일) 더불어민주당이 추진하는 '김건희 특검법'을 두고 "핵폭탄적이라는 입장"이라며 반대 의사를 거듭 밝혔습니다.
#
# 조 대표는 오늘 라디오에 출연해 "국회에서 특검할 때 패스트트랙으로 한 적이 없다. 여야가 합의해 특검이 누가 돼야 할지 주고받고, 그래야 공정성 담보가 되기 때문"이라며 "절차를 무시하고 (민주당이) 특검을 추진하겠다는 것은 굉장히 무리수"라고 말했습니다.
#
# 조 대표는 국회 법제사법위원회 소속으로 김건희 특검법 상임위 통과의 '키맨'으로 꼽힙니다.
#
# 특검법이 패스트트랙으로 지정되려면 법사위 재적 위원(18명)의 5분의 3(11명) 이상 찬성이 필요해 민주당(10명) 의원만으로는 패스트트랙 지정을 할 수 없습니다.
#
# 그는 "민주당 의원들은 (특검을) 국민이 원한다며 역사적 책임을 지라고 하는데 내로남불의 전형"이라며 "선택적인 여론조사 숫자를 들먹이며 일방적으로 밀어붙이는 행위는 민주당의 내로남불, 집단주의적 성향을 반영한다"고 말했습니다.
#
# 그러면서 "민주당이 검수완박(검찰수사권 완전박탈)을 밀어붙였을 때 반대 여론이 65%까지 올라간 적이 있었는데, 그때는 여론 이야기를 안 하지 않았는가"라고 지적했습니다.
#
# 이미지 확대하기
#
# 그러자 민주당 박범계 의원은 페이스북에 "조정훈 의원께"라는 글을 올리며 "김건희 특검법안은 국민들이 결정한다. 우리는 국민을 대변하는 것이다"라고 맞받았습니다.
#
# 박 의원은 "거두절미, 의원님의 소신을 존중한다"면서도 조 대표가 '여야가 합의해 퉁칠 건 퉁치자'고 발언한 것을 두고 "퉁치는 것은 저잣거리에서 장난 삼아 나올법한 얘기이지 국정을 논하는 자리에선 아니라고 생각한다"고 밝혔습니다.
#
# 그러면서 "민주당 덕택으로 의원 되신 것을 지적한 것이 아니다"고 했습니다.
#
# 어제 라디오에 출연해 21대 총선에서 민주당 비례 위성정당이던 더불어시민당 비례대표로 당선됐던 조 대표를 겨냥해 "어떻게 해서 국회에 들어오게 됐는지 한 번 되돌아봤으면 좋겠다"고 언급한 데 대한 부연 설명입니다.
#
# (사진=국회사진기자단, 연합뉴스)
# 제목:
# 양양 낙산에서 건물 진동…숙박업소 투숙객 대피 소동
# 내용:
# ▲위 사진은 기사 내용과 관련이 없습니다.
#
# 지난달 땅 꺼짐으로 편의점 건물 일부가 부서진 강원 양양군 낙산지구의 또 다른 공사 현장 주변에서 소음과 진동으로 숙박업소 투숙객들이 한밤중에 대피하는 소동을 빚었습니다.
#
# 경찰과 소방, 양양군에 따르면 오늘(15일) 오전 2시 24분쯤 양양 낙산지구의 한 숙박업소에서 소음과 진동에 따른 건물 붕괴 우려 신고가 접수됐습니다.
#
# 이에 경찰과 소방, 양양군은 투숙객 17명을 대피시키고 주변을 통제하는 등 안전조치를 취했으며 조사 결과 인근 건물 신축공사장의 작업 과정에서 발생한 소음과 진동 때문으로 확인하고 상황을 마무리했습니다.
#
# 해당 숙박업소와 건물신축 공사장은 인접해 있으며 지난달 땅 꺼짐 사고가 발생한 곳과는 170여ｍ 떨어져 있습니다.
#
# 양양군은 공사장 관계자를 불러 주의 조처를 하는 한편 소음진동관리법에 따라 과태료를 부과하기로 했습니다.
#
# 경찰도 한밤중에 공사한 이유 등에 대해 살펴볼 계획입니다.
#
# 앞서 지난달 3일 낙산지구에서는 건물신축공사장 주변에서 땅 꺼짐 현상이 발생해 편의점 일부가 부서지는 사고가 발생한 바 있습니다.
# 제목:
# 추석날 호텔서 마약 투약한 남녀 검찰에 넘겨져
# 내용:
# 추석날 호텔에서 마약을 투약한 남녀가 검찰에 넘겨졌습니다.
#
# 오늘(15일) 광주 서부경찰서는 향정신성 의약품을 투약한 혐의(마약류 관리에 관한 법률 위반)로 20대 여성 A 씨와 30대 남성 B 씨를 검찰에 송치했습니다.
#
# 경찰에 따르면 이들은 추석 당일인 10일 오전 3시쯤 광주 서구 소재의 한 호텔에서 필로폰을 투약한 혐의를 받습니다.
#
# 두 사람은 마약을 하기 위해 한 채팅 애플리케이션을 통해 만나 이 같은 행위를 벌였습니다.
#
# 투약 후 환각 상태에 빠진 A 씨는 자신의 부모에게 전화를 걸어 "누군가가 나를 해칠 것 같다", "살려달라" 등 두려움을 호소했습니다.
#
# 이후 A 씨 부모가 경찰에 실종 신고를 하면서, 현장에 출동한 경찰이 객실 안에서 마약 투약 정황을 확인했습니다.
#
# A 씨와 B 씨는 모두 마약 간이시약 검사에서 '양성' 반응이 나왔습니다.
#
# 경찰 조사 결과 B 씨는 지난 2월 마약을 구매해 자택에서 마약을 투약한 경험이 있는 것으로 파악됐습니다.
#
# 경찰은 입건 후 이들에 대해 구속 영장을 신청했으나 마약을 구매하고 소지한 B 씨만 구속됐습니다.
#
# (사진=연합뉴스)
# 제목:
# '마약 투여' 유명 남성잡지 모델, 2심도 징역 8개월 실형
# 내용:
# 유명 남성 잡지 모델 출신 30대 여성이 마약을 투약한 혐의로 항소심에서도 실형을 선고받았습니다.
#
# 서울중앙지법 형사항소9부(양경승 부장판사)는 오늘(15일) 마약류관리법 위반(향정) 혐의로 재판에 넘겨진 A 씨(30)에게 1심과 같이 징역 8개월을 선고했습니다.
#
# 40시간의 약물 중독 재활 프로그램과 추징금 30만 원도 함께 명령했습니다.
#
# A 씨는 2020년 10월∼12월 4차례에 걸쳐 지인의 집과 호텔 등에서 마약을 투약한 혐의로 재판에 넘겨졌습니다.
#
# 수사 결과 A 씨의 집에서 마약과 관련 물품들이 발견됐지만, A 씨의 모발과 소변에서는 마약류가 검출되지 않았습니다.
#
# 이를 근거로 A 씨는 소지만 했을 뿐 투약한 사실은 없다며 혐의를 부인했습니다.
#
# 1심 재판부는 그러나 A 씨가 적어도 3차례 마약류를 투약한 사실이 있다고 인정하고 그를 법정에서 구속했습니다.
#
# 1차례 투약 건에 대해서는 증거가 충분하지 않다며 무죄로 봤습니다.
#
# 항소심 재판부는 1심이 무죄로 판단한 투약 건도 "제출된 증거만으로 충분히 피고인이 범행했다는 사실을 인정할 수 있다"며 A 씨의 혐의를 모두 유죄로 인정했습니다.
#
# 다만 "양형에 대해 특별히 변경할 사정은 없는 것으로 보인다"며 1심이 선고한 형량을 그대로 유지했습니다.
#
# (사진=연합뉴스)
# 제목:
# 국민의힘 이용호, 원내대표 출마 선언 "외연 확장 상징 선택해달라"
# 내용:
# 국민의힘 재선 의원인 이용호 의원이 오늘(15일) 오전 국회에서 기자회견을 열어 오는 19일 치러질 원내대표 선거에 출마하겠다는 뜻을 공식적으로 밝혔습니다.
#
# 이 의원은 "국민의힘 앞에 놓인 정치 현실이 간단치 않다"며 "계파를 파괴하고, 선수를 파괴하고, 지역구도를 타파해 새로운 모습으로 당을 탈바꿈시켜야 한다"고 출마의 이유를 밝혔습니다.
#
# 그러면서 "호남이 지역구이며, 실용적이고 중도보수적인 저 이용호를 선택하는 것만으로도 국민의힘은 국민에게 신선한 충격을 줄 것"이라며 "윤석열 정부의 성공, 대한민국의 정상화를 바라신다면 국민의힘 '외연 확장의 상징'저를 선택해 달라"고 호소했습니다.
#
# 이 의원은 또 "법조문이 정치를 대신하는 여의도 정치에 정치를 회복시키겠다"며 비대위원장 직무정지 가처분 신청으로 법정 공방을 벌이고 있는 이준석 전 대표를 에둘러 비판하기도 했습니다.
#
# 이 의원의 출마에 따라 일부 의원들을 중심으로 제기되던 5선의 주호영 의원 추대론은 사실상 무산되고 오는 19일 경선이 치러지게 됐습니다.
#
# (사진=인수위사진기자단 제공, 연합뉴스)
# 제목:
# 피겨 유영, 시즌 첫 국제 대회 쇼트 1위…김예림 5위
# 내용:
# 피겨스케이팅 여자 싱글 간판 유영이 2022-2023시즌 처음 출전한 국제대회 쇼트 프로그램에서 1위에 오르며 기분 좋은 출발을 알렸습니다.
#
# 유영은 미국 뉴욕주 레이크 플래시드에서 열린 국제빙상경기연맹 챌린저 시리즈 US 인터내셔널 클래식 여자 싱글 쇼트 프로그램에서 63.19점을 받았습니다.
#
# 자신의 쇼트 최고점인 78.22점과는 차이가 있지만 이날 연기에 나선 13명 중 1위에 올랐습니다.
#
# 2위인 일본 가와베 마나에 0.51점 앞섰습니다.
#
# 베이징올림픽 6위를 차지한 유영은 새 시즌 그랑프리 출전에 앞서 감각을 점검하기 위해 이번 대회에 출전했습니다.
#
# 유영은 다음 달 28일부터 캐나다에서 열리는 그랑프리 2차 대회와 11월 영국에서 개최되는 4차 대회에 출전할 예정입니다.
#
# 아스토르 피아졸라의 탱고 오토노 포르테노에 맞춰 새 쇼트 프로그램을 준비한 유영은 첫 점프 과제에서 트리플 악셀 대신 더블 악셀을 깔끔하게 뛰었습니다.
#
# 하지만 3회전 연속 점프에서 다운 그레이드 판정을 받아 수행 점수가 깎였고 마지막 트리플 플립 점프에선 어텐션 판정을 받기도 했습니다.
#
# 김예림은 58.32점으로 5위에 올랐습니다.
#
# 이번 시즌 두 차례 그랑프리에 출전하는 김예림은 첫 점프로 3회전 연속 점프를 시도했는데 트리플 러츠에서 어텐션을, 이어진 트리플 토루프에서는 회전수 부족 판정을 받아 수행 점수가 깎였습니다.
#
# 두 번째 점프인 더블 악셀은 실수없이 소화했지만 마지막 점프인 트리플 플립이 다운 그레이드 판정과 함께 더블 플립으로 처리돼 아예 점수를 얻지 못했습니다.
#
# (사진=연합뉴스)
# 제목:
# [영상] 울산서 검거된 '뉴질랜드 경매 가방 속 시신' 용의자…"아이들 친모 유력"
# 내용:
# 뉴질랜드에서 발생한 '가방 속 어린이 시신 사건'의 용의자가 오늘(15일) 새벽 울산에서 붙잡혔습니다. 경찰청에 따르면 울산 중부경찰서는 2018년 뉴질랜드 오클랜드에서 7·10세 친자녀 2명을 살해한 혐의를 받는 40대 여성 A 씨를 울산의 한 아파트에서 검거했습니다. 뉴질랜드에 이민을 가서 현지 국적을 취득했던 A 씨는 범행 이후 한국에 들어와 도피 생활을 한 것으로 알려졌습니다.
#
# 뉴질랜드 경찰은 올해 8월 11일 창고 경매로 판매된 여행 가방 속에서 아동 2명의 시신이 발견되자 수년간 수사를 벌여왔습니다. 경찰청은 A 씨에 대한 공조 요청을 접수한 뒤 뉴질랜드 인터폴과 협력하며 A 씨의 국내 체류 기록, 진료 기록, 전화번호 등을 통해 소재를 추적했습니다. 울산 중부경찰서는 이달 A 씨 소재 첩보를 입수해 잠복수사 끝에 이날 신병을 확보했습니다.
#
# 뉴질랜드 경찰은 A 씨를 뉴질랜드 송환을 요청한 것으로 파악됐습니다. A 씨에 대해서는 2개월 내 서울고등법원의 범죄인 인도 심사가 진행될 예정이며, 법원 판단에 따라 뉴질랜드 측 신병인도 여부가 결정됩니다.
#
# (구성 : 진상명 / 편집 : 장희정 / 제작 : D콘텐츠기획부)

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd
import time
from bs4 import BeautifulSoup as bs
from selenium.webdriver.common.keys import Keys

driver = webdriver.Chrome(ChromeDriverManager().install())

#sbs뉴스-최신뉴스
driver.get("https://news.sbs.co.kr/news/newsflash.do?plink=NEW&cooper=SBSNEWSMAIN")
driver.maximize_window()
time.sleep(1)

#객체화
soup = bs(driver.page_source, 'html.parser')

# %%
#url 보관
#https://news.sbs.co.kr/news/newsflash.do?pageDate=20220915&pageIdx=2
url_list = []
for i in range(1, 6):
    page_url = f'https://news.sbs.co.kr/news/newsflash.do?pageDate=20220915&pageIdx={i}'
    print(page_url)
    driver.get(page_url)

    #웹페이지 변동시 로딩시간 주는게 좋음
    time.sleep(1)

    #soup = bs(driver.page_source, 'html.parser')
    search = soup.select('a.news')
    for i in search:
        url_list.append('https://news.sbs.co.kr/'+i['href'])
# Out:
# https://news.sbs.co.kr/news/newsflash.do?pageDate=20220915&pageIdx=1
# https://news.sbs.co.kr/news/newsflash.do?pageDate=20220915&pageIdx=2
# https://news.sbs.co.kr/news/newsflash.do?pageDate=20220915&pageIdx=3
# https://news.sbs.co.kr/news/newsflash.do?pageDate=20220915&pageIdx=4
# https://news.sbs.co.kr/news/newsflash.do?pageDate=20220915&pageIdx=5

# %% [markdown]
# #### 강사님이 하신 것

# %%
# url 첫페이지 추출
driver = webdriver.Chrome(ChromeDriverManager().install()) 
driver.get("https://news.sbs.co.kr/news/newsflash.do?plink=NEW&cooper=SBSNEWSMAIN")

#select 사용
soup = bs(driver.page_source, 'html.parser')
serach = soup.select('a.news')
for i in serach:
    print('https://news.sbs.co.kr/'+i['href'])

#findall 사용
search2 = soup.find_all('a', class_='news')
for i in search2:
    print('https://news.sbs.co.kr/'+i['href'])
# Out:
# https://news.sbs.co.kr//news/endPage.do?news_id=N1006896931
# https://news.sbs.co.kr//news/endPage.do?news_id=N1006897171
# https://news.sbs.co.kr//news/endPage.do?news_id=N1006896932
# https://news.sbs.co.kr//news/endPage.do?news_id=N1006897038
# https://news.sbs.co.kr//news/endPage.do?news_id=N1006897122
# https://news.sbs.co.kr//news/endPage.do?news_id=N1006897048
# https://news.sbs.co.kr//news/endPage.do?news_id=N1006896384
# https://news.sbs.co.kr//news/endPage.do?news_id=N1006897037
# https://news.sbs.co.kr//news/endPage.do?news_id=N1006897098
# https://news.sbs.co.kr//news/endPage.do?news_id=N1006897084
# https://news.sbs.co.kr//news/endPage.do?news_id=N1006896931
# https://news.sbs.co.kr//news/endPage.do?news_id=N1006897171
# https://news.sbs.co.kr//news/endPage.do?news_id=N1006896932
# https://news.sbs.co.kr//news/endPage.do?news_id=N1006897038
# https://news.sbs.co.kr//news/endPage.do?news_id=N1006897122
# https://news.sbs.co.kr//news/endPage.do?news_id=N1006897048
# https://news.sbs.co.kr//news/endPage.do?news_id=N1006896384
# https://news.sbs.co.kr//news/endPage.do?news_id=N1006897037
# https://news.sbs.co.kr//news/endPage.do?news_id=N1006897098
# https://news.sbs.co.kr//news/endPage.do?news_id=N1006897084

# %%
#1~5페이지의 뉴스 상세 url 수집
url_list = []
for i in range(1,6):
    page_url = 'https://news.sbs.co.kr/news/newsflash.do?plink=NEW&cooper=SBSNEWSMAIN&pageIdx={}'.format(i)
    driver.get(page_url)
    time.sleep(1)
    soup = bs(driver.page_source, 'html.parser')
    search = soup.select('a.news')
    for i in search:
        url_list.append('https://news.sbs.co.kr/'+i['href'])

# %%
title_list=[]
contents_list=[]

for url in url_list:
    driver.get(url)
    time.sleep(1)
    soup = bs(driver.page_source, 'html.parser')
    #제목
    title = soup.select('h2.blind.ir')
#     for i in title:
#         title_list.append(i.text)
    title_list.append(title[0].text)
    
    #내용
    content = soup.select('div.text_area')
#     for i in content:
#         contents_list.append(i.text)

#리스트에 쌓인 내용만 뽑기위해서 인덱스 사용, 즉 []표시 지우기 위해!
    contents_list.append(content[0].text)

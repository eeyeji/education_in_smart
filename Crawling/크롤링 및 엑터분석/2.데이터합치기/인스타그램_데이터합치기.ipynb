# %%
import pandas as pd

# %%
#data1=pd.read_csv('방탄소년단_남준.csv')
#data2=pd.read_csv('방탄소년단_민윤기.csv')
#data3=pd.read_csv('방탄소년단_뷔.csv')
#data4=pd.read_csv('방탄소년단_정국.csv')
#data5=pd.read_csv('방탄소년단_제이홉.csv')
#data6=pd.read_csv('방탄소년단_지민.csv')
#data7=pd.read_csv('방탄소년단_진.csv')

# %%
data1=pd.read_csv('아이돌인스타그램(데이터합치기).csv')
data2=pd.read_csv('블로그크롤링_크리스탈인스타그램.csv')

# %%
data1
# Out:
#        Unnamed: 0                time  \
# 0               0  2022. 3. 30. 23:57
# 1               1   2022. 5. 9. 13:10
# 2               2  2022. 2. 16. 14:00
# 3               3   2022. 9. 29. 8:10
# 4               4   2022. 9. 2. 14:52
# ...           ...                 ...
# 38347        1445   2022. 9. 12. 0:28
# 38348        1446  2022. 8. 23. 14:22
# 38349        1447   2022. 5. 18. 6:25
# 38350        1448  2022. 4. 19. 16:21
# 38351        1449  2022. 1. 21. 18:43
#
#                                                   review  \
# 0              Style news     선미 인스타그램 속 가방, 셋업 코디 패션...
# 1              지수 드라마 [설강화]     220504 배우 김혜윤 인스타그램에 ...
# 2              fashion     제니 화보 패션, 인스타그램 속 캘빈클라인 언더...
# 3              블핑/ 인스타,트위터,SNS     220901 블랙핑크 리사 인스타...
# 4              BLACKPINK     블랙핑크 지수 인스타그램 사진들 모음 202...
# ...                                                  ...
# 38347          4) 스드매 정보     4-2. 웨딩드레스 소재, 종류, 체형별, ...
# ...

# %%
data2
# Out:
#      Unnamed: 0                 time  \
# 0             0    2022. 6. 3. 12:39
# 1             1   2022. 9. 28. 22:00
# 2             2  2022. 11. 11. 14:03
# 3             3  2022. 11. 22. 23:47
# 4             4   2022. 6. 21. 16:13
# ..          ...                  ...
# 229         229   2022. 3. 13. 21:42
# 230         230    2022. 6. 13. 1:22
# 231         231    2022. 3. 6. 12:58
# 232         232   2022. 9. 26. 18:00
# 233         233    2022. 4. 27. 3:06
#
#                                                 review  \
# 0            주간뉴스     제 1회 크리스탈케이 페스티벌 그날의 현장으로 고고!...
# 1            셀럽스타일     폴로 랄프 로렌 ‘폴로 ID’ 미니 숄더 백 : 크...
# 2            취향사람     크리스탈 | 크리스탈 사진 모음 | 정수정 사진모음 ...
# 3            메종드헤어0403 만수점     만수동미용실 #메종드헤어 #크리스탈 ...
# 4            스타패션     수지, 크리스탈, 아이유, 리아, 안유진, 웬디 패션...
# ..                                                 ...
# 229          정보     웰리카 크리스탈 콜라겐 비오틴까지 챙긴 기능성 콜라겐  ...
# 230             SHOPPING     키라키라! 핫한 인스타그램 셀럽백 KAR...
# ...

# %%
data1
del data1['Unnamed: 0']
data1.head()
# Out:
#                  time                                             review  \
# 0  2022. 3. 30. 23:57          Style news     선미 인스타그램 속 가방, 셋업 코디 패션...
# 1   2022. 5. 9. 13:10          지수 드라마 [설강화]     220504 배우 김혜윤 인스타그램에 ...
# 2  2022. 2. 16. 14:00          fashion     제니 화보 패션, 인스타그램 속 캘빈클라인 언더...
# 3   2022. 9. 29. 8:10          블핑/ 인스타,트위터,SNS     220901 블랙핑크 리사 인스타...
# 4   2022. 9. 2. 14:52          BLACKPINK     블랙핑크 지수 인스타그램 사진들 모음 202...
#
#                                                url
# 0     https://blog.naver.com/lovegono/222687454926
# 1     https://blog.naver.com/syr03051/222723113775
# 2  https://blog.naver.com/hyperealism/222649161213
# 3     https://blog.naver.com/syr03051/222885506031
# 4    https://blog.naver.com/fenergy12/222864930875

# %%
data2
del data2['Unnamed: 0']
#data2.rename(columns={'review':'doc'}, inplace=True)
data2.head()
# Out:
#                   time                                             review  \
# 0    2022. 6. 3. 12:39          주간뉴스     제 1회 크리스탈케이 페스티벌 그날의 현장으로 고고!...
# 1   2022. 9. 28. 22:00          셀럽스타일     폴로 랄프 로렌 ‘폴로 ID’ 미니 숄더 백 : 크...
# 2  2022. 11. 11. 14:03          취향사람     크리스탈 | 크리스탈 사진 모음 | 정수정 사진모음 ...
# 3  2022. 11. 22. 23:47          메종드헤어0403 만수점     만수동미용실 #메종드헤어 #크리스탈 ...
# 4   2022. 6. 21. 16:13          스타패션     수지, 크리스탈, 아이유, 리아, 안유진, 웬디 패션...
#
#                                               url
# 0    https://blog.naver.com/soms2565/222757844421
# 1    https://blog.naver.com/rudelulu/222886805489
# 2       https://blog.naver.com/222so/222925981865
# 3  https://blog.naver.com/yellowskys/222935744584
# 4     https://blog.naver.com/7822lsy/222782606400

# %%
df=pd.concat([data1, data2], axis = 0)
#del df['Unnamed: 0']
df.head()
# Out:
#                  time                                             review  \
# 0  2022. 3. 30. 23:57          Style news     선미 인스타그램 속 가방, 셋업 코디 패션...
# 1   2022. 5. 9. 13:10          지수 드라마 [설강화]     220504 배우 김혜윤 인스타그램에 ...
# 2  2022. 2. 16. 14:00          fashion     제니 화보 패션, 인스타그램 속 캘빈클라인 언더...
# 3   2022. 9. 29. 8:10          블핑/ 인스타,트위터,SNS     220901 블랙핑크 리사 인스타...
# 4   2022. 9. 2. 14:52          BLACKPINK     블랙핑크 지수 인스타그램 사진들 모음 202...
#
#                                                url
# 0     https://blog.naver.com/lovegono/222687454926
# 1     https://blog.naver.com/syr03051/222723113775
# 2  https://blog.naver.com/hyperealism/222649161213
# 3     https://blog.naver.com/syr03051/222885506031
# 4    https://blog.naver.com/fenergy12/222864930875

# %%
#del df['Unnamed: 0']
#df

# %%
#중복행 제거
#df.drop_duplicates(inplace=True)

# %%
len(df)
# Out:
# 38586

# %%
df.to_csv('아이돌인스타그램(데이터합치기).csv', encoding='utf-8-sig')
